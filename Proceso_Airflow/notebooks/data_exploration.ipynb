# %% [markdown]
# ## ESTUDIO DE COMO PRETENDE LLEGAR LA DATA

# %% [markdown]
# ---
# ### DEPENDENCIAS
# ---

# %%
import sys
import subprocess
import os

def instalar_si_no(package, pip_name=None):
    try:
        __import__(package)
    except ImportError:
        subprocess.check_call([sys.executable, "-m", "pip", "install", pip_name or package])

paquetes = {
    "pandas": "pandas",
    "pyodbc": "pyodbc",
    "pymssql": "pymssql",
    "sqlalchemy": "sqlalchemy",
    "dotenv": "python-dotenv"
}

for modulo, pip_name in paquetes.items():
    instalar_si_no(modulo, pip_name)
    
import pandas as pd
import pyodbc
from dotenv import load_dotenv
from sqlalchemy import create_engine, text
import urllib.parse
import re
from datetime import datetime

# %% [markdown]
# ---
# ### Cargue de variables de entorno
# ---

# %%
load_dotenv(override=True)
server   = os.getenv("SPACEPARTS_SERVER")
database = os.getenv("SPACEPARTS_DATABASE")
username = os.getenv("SPACEPARTS_USERNAME")
password = os.getenv("SPACEPARTS_PASSWORD")

# %% [markdown]
# ---
# ### Definición de funciones
# ---

# %%
def get_connection(database="master"):
    conn_str = (
        "DRIVER={ODBC Driver 18 for SQL Server};"
        f"SERVER={server};DATABASE={database};"
        f"UID={username};PWD={password};"
        "Encrypt=yes;TrustServerCertificate=no;Connection Timeout=30;"
    )
    return pyodbc.connect(conn_str)

def list_databases():
    """Mapeamos las bases a las cuales la llamada nos va a pertimir acceder"""
    with get_connection("master") as conn:
        cursor = conn.cursor()
        cursor.execute("SELECT name FROM sys.databases;")
        return [row[0] for row in cursor.fetchall()]

def list_tables(database):
    """Lista todas las tablas en una base de datos"""
    with get_connection(database) as conn:
        cursor = conn.cursor()
        cursor.execute("""
            SELECT TABLE_SCHEMA, TABLE_NAME 
            FROM INFORMATION_SCHEMA.TABLES 
            WHERE TABLE_TYPE='BASE TABLE'
            ORDER BY TABLE_SCHEMA, TABLE_NAME;
        """)
        return [f"{row[0]}.{row[1]}" for row in cursor.fetchall()]

def sample_table(database, table_name, n=5):
    """Obtiene una muestra de n filas de una tabla"""
    # Nota: Separa esquema y tabla
    if "." in table_name:
        schema, table = table_name.split(".", 1)
    else:
        schema, table = "dbo", table_name
    
    full_name = f"[{schema}].[{table}]"
    query = f"SELECT TOP {n} * FROM {full_name};"
    odbc_str = (
        f"DRIVER={{ODBC Driver 18 for SQL Server}};"
        f"SERVER={server};DATABASE={database};"
        f"UID={username};PWD={password};"
        "Encrypt=yes;TrustServerCertificate=no;Connection Timeout=30;"
    )
    conn_str = f"mssql+pyodbc:///?odbc_connect={urllib.parse.quote_plus(odbc_str)}"
    engine = create_engine(conn_str)
    
    try:
        df = pd.read_sql(query, engine)
        return df
    except Exception as e:
        print(f"No se pudo leer {full_name}: {e}")
        return None

def _engine(database: str):
    odbc = (
        f"DRIVER={{ODBC Driver 18 for SQL Server}};"
        f"SERVER={server};DATABASE={database};"
        f"UID={username};PWD={password};"
        "Encrypt=yes;TrustServerCertificate=no;Connection Timeout=30;"
    )
    return create_engine(f"mssql+pyodbc:///?odbc_connect={urllib.parse.quote_plus(odbc)}")

def _q(database: str, sql: str):
    eng = _engine(database)
    with eng.connect() as conn:
        return pd.read_sql(text(sql), conn)

def profile_table(database: str, table_name: str, sample_n: int = 5):
    if "." in table_name:
        schema, table = table_name.split(".", 1)
    else:
        schema, table = "dbo", table_name
    obj = f"{schema}.{table}"
    full = f"[{schema}].[{table}]"

    metrics = _q(database, f"""
        SELECT SUM(p.rows) as row_count
        FROM sys.objects o
        JOIN sys.indexes i ON i.object_id = o.object_id
        JOIN sys.partitions p ON p.object_id = i.object_id AND p.index_id = i.index_id
        WHERE o.object_id = OBJECT_ID('{obj}') AND i.index_id IN (0,1);
    """)

    columns = _q(database, f"""
        SELECT c.column_id, c.name AS column_name, t.name AS sql_type,
               c.max_length, c.precision, c.scale, c.is_nullable
        FROM sys.columns c
        JOIN sys.types t ON t.user_type_id = c.user_type_id
        WHERE c.object_id = OBJECT_ID('{obj}')
        ORDER BY c.column_id;
    """)

    try:
        sample = _q(database, f"SELECT TOP {sample_n} * FROM {full};")
    except Exception as e:
        print(f"Muestra no disponible para {full}: {e}")
        sample = pd.DataFrame()

    display(pd.DataFrame([{
        "table_name": obj,
        "row_count": int(metrics.iloc[0]["row_count"]) if not metrics.empty else 0,
        "column_count": len(columns)
    }]))
    display(columns)
    if not sample.empty:
        display(sample)

def profile_many(database: str, tables: list[str], sample_n: int = 5):
    for t in tables:
        print(f"\n--- {t} ---")
        profile_table(database, t, sample_n=sample_n)

# %% [markdown]
# ---
# ### Resultados de estudio origen de data
# ---

# %%
dbs = list_databases()
print("Database disponibles:", dbs)
# Out:
# Database disponibles: ['master', 'SpacePartsCoDW']

# %%
tables = list_tables("master")
tables
# Out:
# ['dbo.sysdac_history_internal', 'dbo.sysdac_instances_internal']

# %% [markdown]
# ### Nota:
# tablas internas del sistema que crea SQL Server (o Azure SQL) cuando se despliegan DAC packages (Data-tier Application Components).
# - **sysdac_history_internal:** guarda metadatos de las operaciones de despliegue del DAC.
# - **sysdac_instances_internal:** registra las instancias del DAC aplicadas en la base.

# %%
tables = list_tables("SpacePartsCoDW")
tables
# Out:
# ['dim.Brands',
#  'dim.Budget-Rate',
#  'dim.Customers',
#  'dim.Employees',
#  'dim.Exchange-Rate',
#  'dim.Invoice-DocType',
#  'dim.Order-DocType',
#  'dim.Order-Status',
#  'dim.Products',
#  'dim.Regions',
#  'fact.Budget',
#  'fact.Forecast',
#  'fact.Invoices',
#  'fact.Orders']

# %% [markdown]
# ---
# ### Segun la pagina que documenta la información:
# ---
#
# - Invoices: facturación + penalizaciones + devoluciones.
# - Orders: pedidos de clientes + fechas de entrega.
# - Budget: metas anuales por cliente/producto/mes.
# - Forecast: revisiones mensuales del budget.

# %%
df_sample = sample_table("SpacePartsCoDW", "dim.Invoice-DocType", n=5)
df_sample
# Out:
#   Billing Document Type Code            Text  Doc. Type Ordinal       Group  \
# 0                         F2  Normal Invoice                  1     Invoice
# 1                         L2   Express Order                  2     Invoice
# 2                         YW        Warranty                  3  Adjustment
# 3                         YR          Return                  4  Adjustment
# 4                         Z2           Other                  5       Other
#
#    Group Ordinal           DWCreatedDate
# 0              1 2023-02-10 14:52:08.297
# 1              1 2023-02-10 14:52:08.297
# 2              2 2023-02-10 14:52:08.297
# 3              2 2023-02-10 14:52:08.297
# 4              3 2023-02-10 14:52:08.297

# %% [markdown]
# ---
# ### Exploración de la data
# ---

# %%
dim_tables = [
 'dim.Brands',
 'dim.Budget-Rate',
 'dim.Customers',
 'dim.Employees',
 'dim.Exchange-Rate',
 'dim.Invoice-DocType',
 'dim.Order-DocType',
 'dim.Order-Status',
 'dim.Products',
 'dim.Regions'
]

profile_many("SpacePartsCoDW", dim_tables, sample_n=5)
# Out:
# --- dim.Brands ---
#    table_name  row_count  column_count
# 0  dim.Brands         20             7
#    column_id       column_name  sql_type  max_length  precision  scale  \
# 0          1          Flagship  nvarchar         100          0      0
# 1          2             Class  nvarchar         100          0      0
# 2          3              Type  nvarchar         100          0      0
# 3          4             Brand  nvarchar         100          0      0
# 4          5         Sub Brand  nvarchar         200          0      0
# 5          6  Product Brand VP  nvarchar         200          0      0
# 6          7     DWCreatedDate  datetime           8         23      3
#
#    is_nullable
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6        False
#        Flagship             Class      Type      Brand            Sub Brand  \
# 0   Other Brand     Private Brand     Value       ASAN  ASAN Terran Systems
# 1   Other Brand     Private Brand  Standard      Bruis                Bruis
# 2   Other Brand     Private Brand     Value  FixIt Co.            FixIt Co.
# 3  Growth Brand  SpaceParts Brand     Value    Galileo  Galileo Aeronautics
# 4  Growth Brand  SpaceParts Brand     Value   GateRite             GateRite
#
#   Product Brand VP           DWCreatedDate
# 0     Nicole Hande 2023-02-10 14:52:07.983
# 1   Siras Invictus 2023-02-10 14:52:07.983
# 2   Carlos Mangold 2023-02-10 14:52:07.983
# 3   Karol Andersen 2023-02-10 14:52:07.983
# 4    Maurizio Prei 2023-02-10 14:52:07.983
# --- dim.Budget-Rate ---
#         table_name  row_count  column_count
# 0  dim.Budget-Rate         15             5
#    column_id      column_name  sql_type  max_length  precision  scale  \
# 0          1             Rate   numeric           9         10      5
# 1          2    From Currency  nvarchar          20          0      0
# 2          3      To Currency  nvarchar          20          0      0
# 3          4  Currency System  nvarchar         100          0      0
# 4          5    DWCreatedDate  datetime           8         23      3
#
#    is_nullable
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#      Rate From Currency To Currency Currency System           DWCreatedDate
# 0  0.4211           ARC         EUR  Arcadia System 2023-02-10 14:52:08.250
# 1  0.6626          BELT         EUR      Sol System 2023-02-10 14:52:08.250
# 2  0.8208           BLO         EUR  Lakonía System 2023-02-10 14:52:08.250
# 3  0.8100           BLT         EUR  Lakonía System 2023-02-10 14:52:08.250
# 4  1.5151           CAL         EUR     Îlos System 2023-02-10 14:52:08.250
# --- dim.Customers ---
#       table_name  row_count  column_count
# 0  dim.Customers       3911            10
#    column_id            column_name  sql_type  max_length  precision  scale  \
# 0          1           Customer Key  nvarchar         200          0      0
# 1          2  Customer Sold-To Name  nvarchar         200          0      0
# 2          3           Account Name  nvarchar         200          0      0
# 3          4       Key Account Name  nvarchar         200          0      0
# 4          5       Transaction Type  nvarchar         200          0      0
# 5          6           Account Type  nvarchar         200          0      0
# 6          7    Key Account Manager  nvarchar         200          0      0
# 7          8        Account Manager  nvarchar         200          0      0
# 8          9                Station  nvarchar         200          0      0
# 9         10          DWCreatedDate  datetime           8         23      3
#
#    is_nullable
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9        False
#   Customer Key                          Customer Sold-To Name  \
# 0    10000101B                           Perilous Acqusitions
# 1    10000102B  Andromeda Shipyards (Darnadus Station Branch)
# 2    10000103B     Pioneering Systems (Phobos Station Branch)
# 3    10000104B                    Miller Space (Mimas Branch)
# 4    10000105B            Pioneering Systems (Îlos IV Branch)
#
#            Account Name     Key Account Name Transaction Type    Account Type  \
# 0  Perilous Acqusitions       No Key Account              B2B  No Key Account
# 1   Andromeda Shipyards  Andromeda Shipyards              B2B     Key Account
# 2    Pioneering Systems   Pioneering Systems              B2B     Key Account
# 3          Miller Space         Miller Space              B2B     Key Account
# 4    Pioneering Systems   Pioneering Systems              B2B     Key Account
#
#       Key Account Manager      Account Manager           Station  \
# 0  No Key Account Manager       Kristin Grifeo    Juliet Station
# 1       Rosalind Franklin  Hector Lightbringer  Darnadus Station
# 2        Carmen San Diago          Susan Horák    Phobos Station
# 3          Matthew Rocket              Ben Guy             Mimas
# 4        Carmen San Diago   Balthazaar Viscari           Îlos IV
#
#             DWCreatedDate
# 0 2023-02-10 14:52:09.250
# 1 2023-02-10 14:52:09.250
# 2 2023-02-10 14:52:09.250
# 3 2023-02-10 14:52:09.250
# 4 2023-02-10 14:52:09.250
# --- dim.Employees ---
#       table_name  row_count  column_count
# 0  dim.Employees        893             5
#    column_id         column_name  sql_type  max_length  precision  scale  \
# 0          1                Role  nvarchar         300          0      0
# 1          2       Employee Name  nvarchar         300          0      0
# 2          3      Employee Email  nvarchar         300          0      0
# 3          4  Data Security Rule  nvarchar         300          0      0
# 4          5       DWCreatedDate  datetime           8         23      3
#
#    is_nullable
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#                      Role   Employee Name                Employee Email  \
# 0    Business Line Leader   Aaneta Gibson   aaneta.gibson@spaceparts.co
# 1    Business Line Leader    Aaron Rogacz    aaron.rogacz@spaceparts.co
# 2  Station Sales Managers   Abilio Decker   abilio.decker@spaceparts.co
# 3         Account Manager  Adam Alexander  adam.alexander@spaceparts.co
# 4         Account Manager     Adam Medina     adam.medina@spaceparts.co
#
#                                   Data Security Rule           DWCreatedDate
# 0  Sales for all accounts, cost & margin only for... 2023-02-10 14:52:07.963
# 1  Sales for all accounts, cost & margin only for... 2023-02-10 14:52:07.963
# 2  All accounts in Stations for which they are re... 2023-02-10 14:52:07.963
# 3  Sales for all stations in which they have a re... 2023-02-10 14:52:07.963
# 4  Sales for all stations in which they have a re... 2023-02-10 14:52:07.963
# --- dim.Exchange-Rate ---
#           table_name  row_count  column_count
# 0  dim.Exchange-Rate      57900             9
#    column_id                  column_name  sql_type  max_length  precision  \
# 0          1                    Rate Type  nvarchar          60          0
# 1          2                From Currency  nvarchar          20          0
# 2          3                  To Currency  nvarchar          20          0
# 3          4              Currency System  nvarchar         100          0
# 4          5                         Rate   numeric           9         10
# 5          6                         Date  datetime           8         23
# 6          7                        Month  nvarchar          40          0
# 7          8  Exchange Rate Composite Key  nvarchar         200          0
# 8          9                DWCreatedDate  datetime           8         23
#
#    scale  is_nullable
# 0      0         True
# 1      0         True
# 2      0         True
# 3      0         True
# 4      5         True
# 5      3         True
# 6      0         True
# 7      0         True
# 8      3        False
#       Rate Type From Currency To Currency Currency System    Rate       Date  \
# 0  Monthly Rate          ILOS         EUR     Îlos System  0.8918 2018-01-12
# 1   Budget Rate           LAK         EUR  Lakonía System  0.9211 2018-01-12
# 2  Monthly Rate           LAK         EUR  Lakonía System  0.9218 2018-01-12
# 3   Budget Rate           MCR         EUR      Sol System  1.7991 2018-01-12
# 4  Monthly Rate           MCR         EUR      Sol System  1.8360 2018-01-12
#
#     Month Exchange Rate Composite Key           DWCreatedDate
# 0  Jan 18  Monthly Rate-AMN-1/12/2018 2023-02-10 14:52:09.007
# 1  Jan 18   Budget Rate-EAS-1/12/2018 2023-02-10 14:52:09.007
# 2  Jan 18  Monthly Rate-EAS-1/12/2018 2023-02-10 14:52:09.007
# 3  Jan 18   Budget Rate-DWA-1/12/2018 2023-02-10 14:52:09.007
# 4  Jan 18  Monthly Rate-DWA-1/12/2018 2023-02-10 14:52:09.007
# --- dim.Invoice-DocType ---
#             table_name  row_count  column_count
# 0  dim.Invoice-DocType          5             6
#    column_id                 column_name  sql_type  max_length  precision  \
# 0          1  Billing Document Type Code  nvarchar          20          0
# 1          2                        Text  nvarchar         200          0
# 2          3           Doc. Type Ordinal       int           4         10
# 3          4                       Group  nvarchar         200          0
# 4          5               Group Ordinal       int           4         10
# 5          6               DWCreatedDate  datetime           8         23
#
#    scale  is_nullable
# 0      0         True
# 1      0         True
# 2      0         True
# 3      0         True
# 4      0         True
# 5      3        False
#   Billing Document Type Code            Text  Doc. Type Ordinal       Group  \
# 0                         F2  Normal Invoice                  1     Invoice
# 1                         L2   Express Order                  2     Invoice
# 2                         YW        Warranty                  3  Adjustment
# 3                         YR          Return                  4  Adjustment
# 4                         Z2           Other                  5       Other
#
#    Group Ordinal           DWCreatedDate
# 0              1 2023-02-10 14:52:08.297
# 1              1 2023-02-10 14:52:08.297
# 2              2 2023-02-10 14:52:08.297
# 3              2 2023-02-10 14:52:08.297
# 4              3 2023-02-10 14:52:08.297
# --- dim.Order-DocType ---
#           table_name  row_count  column_count
# 0  dim.Order-DocType          4             6
#    column_id                     column_name  sql_type  max_length  precision  \
# 0          1  Sales Order Document Type Code  nvarchar          20          0
# 1          2                            Text  nvarchar         200          0
# 2          3               Doc. Type Ordinal       int           4         10
# 3          4                           Group  nvarchar         200          0
# 4          5                   Group Ordinal       int           4         10
# 5          6                   DWCreatedDate  datetime           8         23
#
#    scale  is_nullable
# 0      0         True
# 1      0         True
# 2      0         True
# 3      0         True
# 4      0         True
# 5      3        False
#   Sales Order Document Type Code                   Text  Doc. Type Ordinal  \
# 0                           GLIT  Goods Lost in Transit                  1
# 1                            YLS        Cancelled Order                  2
# 2                            YLF          Express Order                  3
# 3                            YOR         Standard Order                  4
#
#           Group  Group Ordinal           DWCreatedDate
# 0  Cancellation              2 2023-02-10 14:52:07.390
# 1  Cancellation              2 2023-02-10 14:52:07.390
# 2         Order              1 2023-02-10 14:52:07.390
# 3         Order              1 2023-02-10 14:52:07.390
# --- dim.Order-Status ---
#          table_name  row_count  column_count
# 0  dim.Order-Status          6             6
#    column_id                    column_name  sql_type  max_length  precision  \
# 0          1              Order Status Code  nvarchar         100          0
# 1          2              Order Status Text  nvarchar         200          0
# 2          3           Order Status Ordinal       int           4         10
# 3          4             Order Status Group  nvarchar         100          0
# 4          5  Order Status Grouping Ordinal       int           4         10
# 5          6                  DWCreatedDate  datetime           8         23
#
#    scale  is_nullable
# 0      0         True
# 1      0         True
# 2      0         True
# 3      0         True
# 4      0         True
# 5      3        False
#    Order Status Code Order Status Text  Order Status Ordinal  \
# 0          Cancelled   Cancelled Order                     1
# 1    Late Open Order        Late Order                     2
# 2      Open Delivery         WIP Order                     3
# 3  Future Open Order      Future Order                     4
# 4            Overdue     Overdue Order                     5
#
#   Order Status Group  Order Status Grouping Ordinal           DWCreatedDate
# 0          Cancelled                              1 2023-02-10 14:52:08.540
# 1               Open                              2 2023-02-10 14:52:08.540
# 2               Open                              2 2023-02-10 14:52:08.540
# 3               Open                              2 2023-02-10 14:52:08.540
# 4            Overdue                              5 2023-02-10 14:52:08.540
# --- dim.Products ---
#      table_name  row_count  column_count
# 0  dim.Products     256293            18
#     column_id                           column_name  sql_type  max_length  \
# 0           1                        Sub Brand Name  nvarchar         300
# 1           2                   Ship Class for Part  nvarchar         300
# 2           3                          Product Name  nvarchar         300
# 3           4          Product Business Line Leader  nvarchar         300
# 4           5                      Part Fit Grading  nvarchar         300
# 5           6                           Product Key       int           4
# 6           7                               Subtype  nvarchar         300
# 7           8                                  Type  nvarchar         300
# 8           9                       Weight (Tonnes)   numeric           9
# 9          10               Maximum Temperature (K)       int           4
# 10         11  Velocity Tolerance (Meters / Second)       int           4
# 11         12                         Tolerance (g)       int           4
# 12         13                                    MK  nvarchar         300
# 13         14                                 Color  nvarchar         300
# 14         15                     Production Series  nvarchar         300
# 15         16                             Nameplate  nvarchar         300
# 16         17                              Material  nvarchar         300
# 17         18                         DWCreatedDate  datetime           8
#
#     precision  scale  is_nullable
# 0           0      0         True
# 1           0      0         True
# 2           0      0         True
# 3           0      0         True
# 4           0      0         True
# 5          10      0         True
# 6           0      0         True
# 7           0      0         True
# 8          10      5         True
# 9          10      0         True
# 10         10      0         True
# 11         10      0         True
# 12          0      0         True
# 13          0      0         True
# 14          0      0         True
# 15          0      0         True
# 16          0      0         True
# 17         23      3        False
#      Sub Brand Name  Ship Class for Part            Product Name  \
# 0          Krakatoa  Civilian Transports    Liquid Fuel Fuselage
# 1  Plasma Solutions  Civilian Transports      Light Nose Plating
# 2          GateRite  Civilian Transports   Cubic Octagonal Strut
# 3          GateRite  Civilian Transports       Probe-Bodyne Hecs
# 4  Plasma Solutions  Civilian Transports  Thick Fuselage Plating
#
#   Product Business Line Leader    Part Fit Grading  Product Key  \
# 0             Shannon Trujillo  Original Equipment      1000101
# 1                 Britt Martin  Original Equipment      1000102
# 2                 Luigi Rudolf  Original Equipment      1000103
# 3                Heather Kosak  Original Equipment      1000104
# 4                 Britt Martin  Original Equipment      1000105
#
#                         Subtype            Type  Weight (Tonnes)  \
# 0  Liquid Fuel Tanks & Adapters   Fuel & Piping           0.3780
# 1           Light Armor Plating  Hull & Shields           0.0751
# 2        Beams, Panels & Radial      Structural           0.4820
# 3                       Cockpit         Modules           0.3110
# 4           Thick Armor Plating  Hull & Shields           0.7226
#
#    Maximum Temperature (K)  Velocity Tolerance (Meters / Second)  \
# 0                     2058                                     7
# 1                     2257                                     6
# 2                     2077                                    16
# 3                     1237                                    18
# 4                     1855                                    16
#
#    Tolerance (g)   MK  Color Production Series  \
# 0             51  MK1   Blue      SERIES NW-86
# 1             58  MK1   Teal      SERIES YU-51
# 2             54  MK2   Gray      SERIES XC-16
# 3             47  MK2   Navy      SERIES IV-06
# 4             51  MK2  Green      SERIES KH-05
#
#                         Nameplate  \
# 0               Frey and Sons Inc
# 1               Ellis-Johnson PLC
# 2  Cummings, Valdez and Blair Inc
# 3         Pope, Bass and Long PLC
# 4         Pope, Bass and Long PLC
#
#                                           Material           DWCreatedDate
# 0     SERIES NW-86 Liquid Fuel Fuselage MK1 (Blue) 2023-02-10 14:52:07.873
# 1       SERIES YU-51 Light Nose Plating MK1 (Teal) 2023-02-10 14:52:07.873
# 2    SERIES XC-16 Cubic Octagonal Strut MK2 (Gray) 2023-02-10 14:52:07.873
# 3        SERIES IV-06 Probe-Bodyne Hecs MK2 (Navy) 2023-02-10 14:52:07.873
# 4  SERIES KH-05 Thick Fuselage Plating MK2 (Green) 2023-02-10 14:52:07.873
# --- dim.Regions ---
#     table_name  row_count  column_count
# 0  dim.Regions        181            12
#     column_id               column_name  sql_type  max_length  precision  \
# 0           1                       All  nvarchar         200          0
# 1           2                    System  nvarchar         200          0
# 2           3     Interplanetary Region  nvarchar         200          0
# 3           4                 Territory  nvarchar         200          0
# 4           5                   Station  nvarchar         200          0
# 5           6              Station Type  nvarchar         200          0
# 6           7                  Tax Rate   numeric           9         10
# 7           8    System Sales Directors  nvarchar         200          0
# 8           9    Station Sales Managers  nvarchar         200          0
# 9          10  System Regional Managers  nvarchar         200          0
# 10         11       Territory Directors  nvarchar         200          0
# 11         12             DWCreatedDate  datetime           8         23
#
#     scale  is_nullable
# 0       0         True
# 1       0         True
# 2       0         True
# 3       0         True
# 4       0         True
# 5       0         True
# 6       5         True
# 7       0         True
# 8       0         True
# 9       0         True
# 10      0         True
# 11      3        False
#    All        System Interplanetary Region     Territory  \
# 0  All   Îlos System    Îlos VI-VII Region      Îlos VII
# 1  All  Transit Gate   Transit Gate Region  Arcadia Gate
# 2  All   Îlos System    Îlos VI-VII Region      Îlos VII
# 3  All    Sol System          Sol V Region            Io
# 4  All   Îlos System        Îlos IV Region       Îlos IV
#
#                          Station Station Type  Tax Rate  \
# 0               Affligem Station      Station      0.02
# 1  AG Refueling & Supply Station      Station      0.00
# 2             Andromedus Station      Station      0.02
# 3                  Ao Substation      Station      0.04
# 4                 Apollo Station      Station      0.20
#
#   System Sales Directors Station Sales Managers System Regional Managers  \
# 0         Victor Canales     Nicoletta Burcardo            Nicholas Basa
# 1        Garrett Novotná       Fermín Serraglio          Amy Blankenship
# 2         Victor Canales       Madeleine Valdez            Nicholas Basa
# 3            Martine Roś          Shade Tabaxii             Alyssa Ariño
# 4         Victor Canales            Felisa Long  Christopher Jędraszczyk
#
#   Territory Directors           DWCreatedDate
# 0      Patrick Larson 2023-02-10 14:52:09.130
# 1      Michael Huerta 2023-02-10 14:52:09.130
# 2      Patrick Larson 2023-02-10 14:52:09.130
# 3       Agnès Poirier 2023-02-10 14:52:09.130
# 4       Evita Calgari 2023-02-10 14:52:09.130

# %% [markdown]
# ---
# ### Limpieza y estandarización.
# ---

# %%
DB = "SpacePartsCoDW"

def _engine(database: str):
    odbc = (
        f"DRIVER={{ODBC Driver 18 for SQL Server}};"
        f"SERVER={server};DATABASE={database};"
        f"UID={username};PWD={password};"
        "Encrypt=yes;TrustServerCertificate=no;Connection Timeout=30;"
    )
    return create_engine(f"mssql+pyodbc:///?odbc_connect={urllib.parse.quote_plus(odbc)}")

def read_dim(table: str, top: int|None=None) -> pd.DataFrame:
    """Lee dim.<table> de SpacePartsCoDW; usa TOP si lo pasas."""
    eng = _engine(DB)
    full = f"[dim].[{table}]"
    sql = f"SELECT {'TOP '+str(top) if top else ''} * FROM {full};"
    with eng.connect() as conn:
        return pd.read_sql(text(sql), conn)


dim_brands         = read_dim("Brands")
dim_budget_rate    = read_dim("Budget-Rate")
dim_customers      = read_dim("Customers")
dim_employees      = read_dim("Employees")
dim_exchange_rate  = read_dim("Exchange-Rate")
dim_invoice_doctype= read_dim("Invoice-DocType")
dim_order_doctype  = read_dim("Order-DocType")
dim_order_status   = read_dim("Order-Status")
dim_products       = read_dim("Products")     
dim_regions        = read_dim("Regions")

# %%
# Normaliza nombres de columnas → snake_case sin espacios/acentos/guiones
def std_colname(s: str) -> str:
    s = s.strip()
    s = re.sub(r"[^\w]+", "_", s, flags=re.UNICODE)   # espacios, guiones, etc → _
    s = re.sub(r"__+", "_", s)
    return s.strip("_").lower()

def standardize_columns(df: pd.DataFrame) -> pd.DataFrame:
    out = df.copy()
    out.columns = [std_colname(c) for c in df.columns]
    return out

# Limpia strings (trim, colapsa espacios), opcional upper/lower
def clean_string_series(s: pd.Series, to="asis") -> pd.Series:
    s = s.astype("string")
    s = s.str.replace(r"\s+", " ", regex=True).str.strip()
    if to == "upper": s = s.str.upper()
    if to == "lower": s = s.str.lower()
    return s

# Casteo robusto por tipo
def to_datetime_safe(s: pd.Series) -> pd.Series:
    return pd.to_datetime(s, errors="coerce", utc=False)

def to_int_safe(s: pd.Series) -> pd.Series:
    return pd.to_numeric(s, errors="coerce").astype("Int64")

def to_float_safe(s: pd.Series) -> pd.Series:
    return pd.to_numeric(s, errors="coerce").astype("Float64")

# Inferencia heurística por nombre de columna
def infer_cast(df: pd.DataFrame) -> pd.DataFrame:
    out = df.copy()
    for c in out.columns:
        cl = c.lower()
        # fechas
        if any(k in cl for k in ["date", "dt", "created"]):
            out[c] = to_datetime_safe(out[c])
            continue
        # claves numéricas típicas
        if cl.endswith("_key") or cl in {"product_key","customer_key","brand_key","region_key","order_status_ordinal","doc_type_ordinal"}:
            out[c] = to_int_safe(out[c])
            continue
        # cantidades/valores/rates
        if any(k in cl for k in ["rate","value","amount","quantity","volume","tax","penalt","weight","temperature","tolerance"]):
            out[c] = to_float_safe(out[c])
            continue
        # emails/monedas/textos → string limpiado
        if any(k in cl for k in ["email","currency","name","text","group","class","type","station","system","color","material","series","mk","role","manager"]):
            out[c] = clean_string_series(out[c], to="asis")
            continue
        # por defecto: si es object, limpiar
        if out[c].dtype == "object":
            out[c] = clean_string_series(out[c], to="asis")
    return out

# Reglas específicas por tabla/columna (sobrescriben la inferencia)
# usa nombres de tabla en snake_case (p. ej., 'dim_brands')
TYPE_HINTS = {
    "dim_brands": {
        "dwcreateddate": "datetime",
    },
    "dim_budget_rate": {
        "rate": "float",
        "from_currency": "upper",
        "to_currency": "upper",
        "dwcreateddate": "datetime",
    },
    "dim_customers": {
        "customer_key": "string",
        "station": "string",
        "dwcreateddate": "datetime",
    },
    "dim_employees": {
        "employee_email": "lower",
        "dwcreateddate": "datetime",
    },
    "dim_exchange_rate": {
        "rate": "float",
        "date": "datetime",
        "from_currency": "upper",
        "to_currency": "upper",
        "dwcreateddate": "datetime",
    },
    "dim_invoice_doctype": {
        "doc_type_ordinal": "int",
        "group_ordinal": "int",
        "dwcreateddate": "datetime",
    },
    "dim_order_doctype": {
        "doc_type_ordinal": "int",
        "group_ordinal": "int",
        "dwcreateddate": "datetime",
    },
    "dim_order_status": {
        "order_status_ordinal": "int",
        "order_status_grouping_ordinal": "int",
        "dwcreateddate": "datetime",
    },
    "dim_products": {
        "product_key": "int",
        "weight_tonnes": "float",
        "maximum_temperature_k": "int",
        "velocity_tolerance_meters_second": "int",
        "tolerance_g": "int",
        "dwcreateddate": "datetime",
    },
    "dim_regions": {
        "tax_rate": "float",
        "dwcreateddate": "datetime",
    },
}

def apply_type_hints(df: pd.DataFrame, table_name_snake: str) -> pd.DataFrame:
    out = df.copy()
    hints = TYPE_HINTS.get(table_name_snake, {})
    for col, kind in hints.items():
        if col not in out.columns: 
            continue
        if kind == "datetime":
            out[col] = to_datetime_safe(out[col])
        elif kind == "int":
            out[col] = to_int_safe(out[col])
        elif kind == "float":
            out[col] = to_float_safe(out[col])
        elif kind == "upper":
            out[col] = clean_string_series(out[col], to="upper")
        elif kind == "lower":
            out[col] = clean_string_series(out[col], to="lower")
        elif kind == "string":
            out[col] = clean_string_series(out[col], to="asis")
    return out

# %%
def profile_df(df: pd.DataFrame, table_label: str, sample_n: int = 5):
    # resumen general
    summary = pd.DataFrame([{
        "table_name": table_label,
        "row_count": len(df),
        "column_count": df.shape[1]
    }])

    # métricas por columna
    cols = []
    for c in df.columns:
        s = df[c]
        dtype = str(s.dtype)
        n_null = int(s.isna().sum())
        n_dist = int(s.nunique(dropna=True))
        ex = s.dropna().head(3).tolist()
        item = {
            "column": c,
            "dtype": dtype,
            "nulls": n_null,
            "null_pct": round(100 * n_null / max(len(s),1), 2),
            "distinct": n_dist,
            "example_values": ex
        }
        if pd.api.types.is_numeric_dtype(s):
            item.update({
                "min": s.min(),
                "max": s.max(),
                "mean": s.mean()
            })
        elif pd.api.types.is_datetime64_any_dtype(s):
            item.update({
                "min": s.min(),
                "max": s.max()
            })
        else:
            # longitud media para strings
            try:
                item.update({"avg_len": float(s.astype("string").str.len().mean())})
            except Exception:
                item.update({"avg_len": None})
        cols.append(item)

    columns_profile = pd.DataFrame(cols)
    display(summary)
    display(columns_profile.sort_values(["dtype","column"]))
    display(df.head(sample_n))

    return summary, columns_profile

# %%
# (1) Estandariza nombres, (2) inferencia, (3) hints específicos, (4) perfil
def clean_and_profile(df: pd.DataFrame, label: str):
    t_snake = std_colname(label)
    d0 = standardize_columns(df)
    d1 = infer_cast(d0)
    d2 = apply_type_hints(d1, t_snake)
    print(f"\n--- {label} ---")
    return profile_df(d2, label, sample_n=5)

dim_brands_sum, dim_brands_cols = clean_and_profile(dim_brands, "dim.Brands")
dim_budget_rate_sum, dim_budget_rate_cols = clean_and_profile(dim_budget_rate, "dim.Budget-Rate")
dim_customers_sum, dim_customers_cols = clean_and_profile(dim_customers, "dim.Customers")
dim_employees_sum, dim_employees_cols = clean_and_profile(dim_employees, "dim.Employees")
dim_exchange_rate_sum, dim_exchange_rate_cols = clean_and_profile(dim_exchange_rate, "dim.Exchange-Rate")
dim_invoice_dtype_sum, dim_invoice_dtype_cols = clean_and_profile(dim_invoice_doctype, "dim.Invoice-DocType")
dim_order_dtype_sum, dim_order_dtype_cols = clean_and_profile(dim_order_doctype, "dim.Order-DocType")
dim_order_status_sum, dim_order_status_cols = clean_and_profile(dim_order_status, "dim.Order-Status")
dim_products_sum, dim_products_cols = clean_and_profile(dim_products, "dim.Products")
dim_regions_sum, dim_regions_cols = clean_and_profile(dim_regions, "dim.Regions")
# Out:
# --- dim.Brands ---
#    table_name  row_count  column_count
# 0  dim.Brands         20             7
#              column           dtype  nulls  null_pct  distinct  \
# 6     dwcreateddate  datetime64[ns]      0       0.0         1
# 3             brand          string      0       0.0        14
# 1             class          string      0       0.0         2
# 0          flagship          string      0       0.0         3
# 5  product_brand_vp          string      0       0.0        14
# 4         sub_brand          string      0       0.0        20
# 2              type          string      0       0.0         4
#
#                                       example_values  avg_len  \
# 6  [2023-02-10 14:52:07.983000, 2023-02-10 14:52:...      NaN
# 3                           [ASAN, Bruis, FixIt Co.]     6.55
# 1      [Private Brand, Private Brand, Private Brand]    14.80
# 0            [Other Brand, Other Brand, Other Brand]    12.50
# 5     [Nicole Hande, Siras Invictus, Carlos Mangold]    12.90
# 4            [ASAN Terran Systems, Bruis, FixIt Co.]    10.95
# 2                           [Value, Standard, Value]     6.65
#
#                       min                     max
# 6 2023-02-10 14:52:07.983 2023-02-10 14:52:07.983
# 3                     NaT                     NaT
# 1                     NaT                     NaT
# 0                     NaT                     NaT
# 5                     NaT                     NaT
# 4                     NaT                     NaT
# 2                     NaT                     NaT
#        flagship             class      type      brand            sub_brand  \
# 0   Other Brand     Private Brand     Value       ASAN  ASAN Terran Systems
# 1   Other Brand     Private Brand  Standard      Bruis                Bruis
# 2   Other Brand     Private Brand     Value  FixIt Co.            FixIt Co.
# 3  Growth Brand  SpaceParts Brand     Value    Galileo  Galileo Aeronautics
# 4  Growth Brand  SpaceParts Brand     Value   GateRite             GateRite
#
#   product_brand_vp           dwcreateddate
# 0     Nicole Hande 2023-02-10 14:52:07.983
# 1   Siras Invictus 2023-02-10 14:52:07.983
# 2   Carlos Mangold 2023-02-10 14:52:07.983
# 3   Karol Andersen 2023-02-10 14:52:07.983
# 4    Maurizio Prei 2023-02-10 14:52:07.983
# --- dim.Budget-Rate ---
#         table_name  row_count  column_count
# 0  dim.Budget-Rate         15             5
#             column           dtype  nulls  null_pct  distinct  \
# 0             rate         Float64      0       0.0        15
# 4    dwcreateddate  datetime64[ns]      0       0.0         1
# 3  currency_system          string      0       0.0         6
# 1    from_currency          string      0       0.0        15
# 2      to_currency          string      0       0.0         1
#
#                                       example_values  \
# 0                           [0.4211, 0.6626, 0.8208]
# 4  [2023-02-10 14:52:08.250000, 2023-02-10 14:52:...
# 3       [Arcadia System, Sol System, Lakonía System]
# 1                                   [ARC, BELT, BLO]
# 2                                    [EUR, EUR, EUR]
#
#                           min                         max      mean  avg_len
# 0                      0.4169                        3.12  1.117807      NaN
# 4  2023-02-10 14:52:08.250000  2023-02-10 14:52:08.250000       NaN      NaN
# 3                         NaN                         NaN       NaN     11.8
# 1                         NaN                         NaN       NaN      3.4
# 2                         NaN                         NaN       NaN      3.0
#      rate from_currency to_currency currency_system           dwcreateddate
# 0  0.4211           ARC         EUR  Arcadia System 2023-02-10 14:52:08.250
# 1  0.6626          BELT         EUR      Sol System 2023-02-10 14:52:08.250
# 2  0.8208           BLO         EUR  Lakonía System 2023-02-10 14:52:08.250
# 3    0.81           BLT         EUR  Lakonía System 2023-02-10 14:52:08.250
# 4  1.5151           CAL         EUR     Îlos System 2023-02-10 14:52:08.250
# --- dim.Customers ---
#       table_name  row_count  column_count
# 0  dim.Customers       3911            10
#                   column           dtype  nulls  null_pct  distinct  \
# 9          dwcreateddate  datetime64[ns]      0       0.0         1
# 7        account_manager          string      0       0.0       604
# 2           account_name          string      0       0.0      1978
# 5           account_type          string      0       0.0         3
# 0           customer_key          string   3911     100.0         0
# 1  customer_sold_to_name          string      0       0.0      3136
# 6    key_account_manager          string      0       0.0        14
# 3       key_account_name          string      0       0.0        14
# 8                station          string      0       0.0       179
# 4       transaction_type          string      0       0.0         3
#
#                                       example_values    avg_len  \
# 9  [2023-02-10 14:52:09.250000, 2023-02-10 14:52:...        NaN
# 7  [Kristin Grifeo, Hector Lightbringer, Susan Ho...  14.115827
# 2  [Perilous Acqusitions, Andromeda Shipyards, Pi...  18.543595
# 5         [No Key Account, Key Account, Key Account]  12.350550
# 0                                                 []        NaN
# 1  [Perilous Acqusitions, Andromeda Shipyards (Da...  30.007926
# 6  [No Key Account Manager, Rosalind Franklin, Ca...  16.975454
# 3  [No Key Account, Andromeda Shipyards, Pioneeri...  16.392994
# 8  [Juliet Station, Darnadus Station, Phobos Stat...  14.117106
# 4                                    [B2B, B2B, B2B]   3.000000
#
#                       min                     max
# 9 2023-02-10 14:52:09.250 2023-02-10 14:52:09.250
# 7                     NaT                     NaT
# 2                     NaT                     NaT
# 5                     NaT                     NaT
# 0                     NaT                     NaT
# 1                     NaT                     NaT
# 6                     NaT                     NaT
# 3                     NaT                     NaT
# 8                     NaT                     NaT
# 4                     NaT                     NaT
#   customer_key                          customer_sold_to_name  \
# 0         <NA>                           Perilous Acqusitions
# 1         <NA>  Andromeda Shipyards (Darnadus Station Branch)
# 2         <NA>     Pioneering Systems (Phobos Station Branch)
# 3         <NA>                    Miller Space (Mimas Branch)
# 4         <NA>            Pioneering Systems (Îlos IV Branch)
#
#            account_name     key_account_name transaction_type    account_type  \
# 0  Perilous Acqusitions       No Key Account              B2B  No Key Account
# 1   Andromeda Shipyards  Andromeda Shipyards              B2B     Key Account
# 2    Pioneering Systems   Pioneering Systems              B2B     Key Account
# 3          Miller Space         Miller Space              B2B     Key Account
# 4    Pioneering Systems   Pioneering Systems              B2B     Key Account
#
#       key_account_manager      account_manager           station  \
# 0  No Key Account Manager       Kristin Grifeo    Juliet Station
# 1       Rosalind Franklin  Hector Lightbringer  Darnadus Station
# 2        Carmen San Diago          Susan Horák    Phobos Station
# 3          Matthew Rocket              Ben Guy             Mimas
# 4        Carmen San Diago   Balthazaar Viscari           Îlos IV
#
#             dwcreateddate
# 0 2023-02-10 14:52:09.250
# 1 2023-02-10 14:52:09.250
# 2 2023-02-10 14:52:09.250
# 3 2023-02-10 14:52:09.250
# 4 2023-02-10 14:52:09.250
# --- dim.Employees ---
#       table_name  row_count  column_count
# 0  dim.Employees        893             5
#                column           dtype  nulls  null_pct  distinct  \
# 4       dwcreateddate  datetime64[ns]      0       0.0         1
# 3  data_security_rule          string      0       0.0         6
# 2      employee_email          string      0       0.0       867
# 1       employee_name          string      0       0.0       867
# 0                role          string      0       0.0         8
#
#                                       example_values    avg_len  \
# 4  [2023-02-10 14:52:07.963000, 2023-02-10 14:52:...        NaN
# 3  [Sales for all accounts, cost & margin only fo...  99.287794
# 2  [aaneta.gibson@spaceparts.co, aaron.rogacz@spa...  27.293393
# 1       [Aaneta Gibson, Aaron Rogacz, Abilio Decker]  13.431131
# 0  [Business Line Leader, Business Line Leader, S...  16.899216
#
#                       min                     max
# 4 2023-02-10 14:52:07.963 2023-02-10 14:52:07.963
# 3                     NaT                     NaT
# 2                     NaT                     NaT
# 1                     NaT                     NaT
# 0                     NaT                     NaT
#                      role   employee_name                employee_email  \
# 0    Business Line Leader   Aaneta Gibson   aaneta.gibson@spaceparts.co
# 1    Business Line Leader    Aaron Rogacz    aaron.rogacz@spaceparts.co
# 2  Station Sales Managers   Abilio Decker   abilio.decker@spaceparts.co
# 3         Account Manager  Adam Alexander  adam.alexander@spaceparts.co
# 4         Account Manager     Adam Medina     adam.medina@spaceparts.co
#
#                                   data_security_rule           dwcreateddate
# 0  Sales for all accounts, cost & margin only for... 2023-02-10 14:52:07.963
# 1  Sales for all accounts, cost & margin only for... 2023-02-10 14:52:07.963
# 2  All accounts in Stations for which they are re... 2023-02-10 14:52:07.963
# 3  Sales for all stations in which they have a re... 2023-02-10 14:52:07.963
# 4  Sales for all stations in which they have a re... 2023-02-10 14:52:07.963
# --- dim.Exchange-Rate ---
#           table_name  row_count  column_count
# 0  dim.Exchange-Rate      57900             9
#                         column           dtype  nulls  null_pct  distinct  \
# 4                         rate         Float64      0       0.0       774
# 0                    rate_type         Float64  57900     100.0         0
# 7  exchange_rate_composite_key           Int64  57900     100.0         0
# 5                         date  datetime64[ns]      0       0.0      1930
# 8                dwcreateddate  datetime64[ns]      0       0.0         2
# 3              currency_system          string      0       0.0         6
# 1                from_currency          string      0       0.0        15
# 6                        month          string      0       0.0        64
# 2                  to_currency          string      0       0.0         1
#
#                                       example_values  \
# 4                           [0.8918, 0.9211, 0.9218]
# 0                                                 []
# 7                                                 []
# 5  [2018-01-12 00:00:00, 2018-01-12 00:00:00, 201...
# 8  [2023-02-10 14:52:09.007000, 2023-02-10 14:52:...
# 3      [Îlos System, Lakonía System, Lakonía System]
# 1                                   [ILOS, LAK, LAK]
# 6                           [Jan 18, Jan 18, Jan 18]
# 2                                    [EUR, EUR, EUR]
#
#                           min                         max      mean  avg_len
# 4                      0.3808                      3.3874  1.121654      NaN
# 0                        <NA>                        <NA>      <NA>      NaN
# 7                        <NA>                        <NA>      <NA>      NaN
# 5         2018-01-01 00:00:00         2023-04-14 00:00:00       NaN      NaN
# 8  2023-02-10 14:52:09.007000  2023-02-10 14:52:09.243000       NaN      NaN
# 3                         NaN                         NaN       NaN     11.8
# 1                         NaN                         NaN       NaN      3.4
# 6                         NaN                         NaN       NaN      6.0
# 2                         NaN                         NaN       NaN      3.0
#    rate_type from_currency to_currency currency_system    rate       date  \
# 0       <NA>          ILOS         EUR     Îlos System  0.8918 2018-01-12
# 1       <NA>           LAK         EUR  Lakonía System  0.9211 2018-01-12
# 2       <NA>           LAK         EUR  Lakonía System  0.9218 2018-01-12
# 3       <NA>           MCR         EUR      Sol System  1.7991 2018-01-12
# 4       <NA>           MCR         EUR      Sol System   1.836 2018-01-12
#
#     month  exchange_rate_composite_key           dwcreateddate
# 0  Jan 18                         <NA> 2023-02-10 14:52:09.007
# 1  Jan 18                         <NA> 2023-02-10 14:52:09.007
# 2  Jan 18                         <NA> 2023-02-10 14:52:09.007
# 3  Jan 18                         <NA> 2023-02-10 14:52:09.007
# 4  Jan 18                         <NA> 2023-02-10 14:52:09.007
# --- dim.Invoice-DocType ---
#             table_name  row_count  column_count
# 0  dim.Invoice-DocType          5             6
#                        column           dtype  nulls  null_pct  distinct  \
# 2            doc_type_ordinal           Int64      0       0.0         5
# 4               group_ordinal           Int64      0       0.0         3
# 5               dwcreateddate  datetime64[ns]      0       0.0         1
# 0  billing_document_type_code          string      0       0.0         5
# 3                       group          string      0       0.0         3
# 1                        text          string      0       0.0         5
#
#                                       example_values  avg_len  \
# 2                                          [1, 2, 3]      NaN
# 4                                          [1, 1, 2]      NaN
# 5  [2023-02-10 14:52:08.297000, 2023-02-10 14:52:...      NaN
# 0                                       [F2, L2, YW]      2.0
# 3                     [Invoice, Invoice, Adjustment]      7.8
# 1          [Normal Invoice, Express Order, Warranty]      9.2
#
#                           min                         max  mean
# 2                           1                           5   3.0
# 4                           1                           3   1.8
# 5  2023-02-10 14:52:08.297000  2023-02-10 14:52:08.297000   NaN
# 0                         NaN                         NaN   NaN
# 3                         NaN                         NaN   NaN
# 1                         NaN                         NaN   NaN
#   billing_document_type_code            text  doc_type_ordinal       group  \
# 0                         F2  Normal Invoice                 1     Invoice
# 1                         L2   Express Order                 2     Invoice
# 2                         YW        Warranty                 3  Adjustment
# 3                         YR          Return                 4  Adjustment
# 4                         Z2           Other                 5       Other
#
#    group_ordinal           dwcreateddate
# 0              1 2023-02-10 14:52:08.297
# 1              1 2023-02-10 14:52:08.297
# 2              2 2023-02-10 14:52:08.297
# 3              2 2023-02-10 14:52:08.297
# 4              3 2023-02-10 14:52:08.297
# --- dim.Order-DocType ---
#           table_name  row_count  column_count
# 0  dim.Order-DocType          4             6
#                            column           dtype  nulls  null_pct  distinct  \
# 2                doc_type_ordinal           Int64      0       0.0         4
# 4                   group_ordinal           Int64      0       0.0         2
# 5                   dwcreateddate  datetime64[ns]      0       0.0         1
# 3                           group          string      0       0.0         2
# 0  sales_order_document_type_code          string      0       0.0         4
# 1                            text          string      0       0.0         4
#
#                                       example_values  avg_len  \
# 2                                          [1, 2, 3]      NaN
# 4                                          [2, 2, 1]      NaN
# 5  [2023-02-10 14:52:07.390000, 2023-02-10 14:52:...      NaN
# 3                [Cancellation, Cancellation, Order]     8.50
# 0                                   [GLIT, YLS, YLF]     3.25
# 1  [Goods Lost in Transit, Cancelled Order, Expre...    15.75
#
#                           min                         max  mean
# 2                           1                           4   2.5
# 4                           1                           2   1.5
# 5  2023-02-10 14:52:07.390000  2023-02-10 14:52:07.390000   NaN
# 3                         NaN                         NaN   NaN
# 0                         NaN                         NaN   NaN
# 1                         NaN                         NaN   NaN
#   sales_order_document_type_code                   text  doc_type_ordinal  \
# 0                           GLIT  Goods Lost in Transit                 1
# 1                            YLS        Cancelled Order                 2
# 2                            YLF          Express Order                 3
# 3                            YOR         Standard Order                 4
#
#           group  group_ordinal           dwcreateddate
# 0  Cancellation              2 2023-02-10 14:52:07.390
# 1  Cancellation              2 2023-02-10 14:52:07.390
# 2         Order              1 2023-02-10 14:52:07.390
# 3         Order              1 2023-02-10 14:52:07.390
# --- dim.Order-Status ---
#          table_name  row_count  column_count
# 0  dim.Order-Status          6             6
#                           column           dtype  nulls  null_pct  distinct  \
# 4  order_status_grouping_ordinal           Int64      0       0.0         4
# 2           order_status_ordinal           Int64      0       0.0         6
# 5                  dwcreateddate  datetime64[ns]      0       0.0         1
# 0              order_status_code          string      0       0.0         6
# 3             order_status_group          string      0       0.0         4
# 1              order_status_text          string      0       0.0         6
#
#                                       example_values    avg_len  \
# 4                                          [1, 2, 2]        NaN
# 2                                          [1, 2, 3]        NaN
# 5  [2023-02-10 14:52:08.540000, 2023-02-10 14:52:...        NaN
# 0        [Cancelled, Late Open Order, Open Delivery]  11.500000
# 3                            [Cancelled, Open, Open]   6.000000
# 1           [Cancelled Order, Late Order, WIP Order]  12.166667
#
#                           min                         max  mean
# 4                           1                           6   3.0
# 2                           1                           6   3.5
# 5  2023-02-10 14:52:08.540000  2023-02-10 14:52:08.540000   NaN
# 0                         NaN                         NaN   NaN
# 3                         NaN                         NaN   NaN
# 1                         NaN                         NaN   NaN
#    order_status_code order_status_text  order_status_ordinal  \
# 0          Cancelled   Cancelled Order                     1
# 1    Late Open Order        Late Order                     2
# 2      Open Delivery         WIP Order                     3
# 3  Future Open Order      Future Order                     4
# 4            Overdue     Overdue Order                     5
#
#   order_status_group  order_status_grouping_ordinal           dwcreateddate
# 0          Cancelled                              1 2023-02-10 14:52:08.540
# 1               Open                              2 2023-02-10 14:52:08.540
# 2               Open                              2 2023-02-10 14:52:08.540
# 3               Open                              2 2023-02-10 14:52:08.540
# 4            Overdue                              5 2023-02-10 14:52:08.540
# --- dim.Products ---
#      table_name  row_count  column_count
# 0  dim.Products     256293            18
#                               column           dtype  nulls  null_pct  \
# 8                      weight_tonnes         Float64      0       0.0
# 9              maximum_temperature_k           Int64      0       0.0
# 5                        product_key           Int64      0       0.0
# 11                       tolerance_g           Int64      0       0.0
# 10  velocity_tolerance_meters_second           Int64      0       0.0
# 17                     dwcreateddate  datetime64[ns]      0       0.0
# 13                             color          string      0       0.0
# 16                          material          string      0       0.0
# 12                                mk          string      0       0.0
# 15                         nameplate          string      0       0.0
# 4                   part_fit_grading          string      0       0.0
# 3       product_business_line_leader          string      0       0.0
# 2                       product_name          string      0       0.0
# 14                 production_series          string      0       0.0
# 1                ship_class_for_part          string      0       0.0
# 0                     sub_brand_name          string      0       0.0
# 6                            subtype          string      0       0.0
# 7                               type          string      0       0.0
#
#     distinct                                     example_values    avg_len  \
# 8      14364                             [0.378, 0.0751, 0.482]        NaN
# 9       2295                                 [2058, 2257, 2077]        NaN
# 5     256293                        [1000101, 1000102, 1000103]        NaN
# 11        49                                       [51, 58, 54]        NaN
# 10        92                                         [7, 6, 16]        NaN
# 17        15  [2023-02-10 14:52:07.873000, 2023-02-10 14:52:...        NaN
# 13        12                                 [Blue, Teal, Gray]   4.608776
# 16    256045  [SERIES NW-86 Liquid Fuel Fuselage MK1 (Blue),...  50.474906
# 12         3                                    [MK1, MK1, MK2]   3.000000
# 15        23  [Frey and Sons Inc, Ellis-Johnson PLC, Cumming...  21.606255
# 4          2  [Original Equipment, Original Equipment, Origi...  18.239527
# 3         76     [Shannon Trujillo, Britt Martin, Luigi Rudolf]  13.199791
# 2        573  [Liquid Fuel Fuselage, Light Nose Plating, Cub...  25.866130
# 14     66037         [SERIES NW-86, SERIES YU-51, SERIES XC-16]  12.000000
# 1          3  [Civilian Transports, Civilian Transports, Civ...  19.045386
# 0         20             [Krakatoa, Plasma Solutions, GateRite]  14.232156
# 6         45  [Liquid Fuel Tanks & Adapters, Light Armor Pla...  17.262680
# 7          9        [Fuel & Piping, Hull & Shields, Structural]  12.424202
#
#                            min                         max          mean
# 8                          0.0                      42.998  7.891469e-01
# 9                          903                        4099  2.039388e+03
# 5                      1000101                     1256393  1.128247e+06
# 11                          24                         157  5.102957e+01
# 10                           0                         131  1.806905e+01
# 17  2023-02-10 14:52:07.873000  2023-02-10 14:52:16.610000           NaN
# 13                         NaN                         NaN           NaN
# 16                         NaN                         NaN           NaN
# 12                         NaN                         NaN           NaN
# 15                         NaN                         NaN           NaN
# 4                          NaN                         NaN           NaN
# 3                          NaN                         NaN           NaN
# 2                          NaN                         NaN           NaN
# 14                         NaN                         NaN           NaN
# 1                          NaN                         NaN           NaN
# 0                          NaN                         NaN           NaN
# 6                          NaN                         NaN           NaN
# 7                          NaN                         NaN           NaN
#      sub_brand_name  ship_class_for_part            product_name  \
# 0          Krakatoa  Civilian Transports    Liquid Fuel Fuselage
# 1  Plasma Solutions  Civilian Transports      Light Nose Plating
# 2          GateRite  Civilian Transports   Cubic Octagonal Strut
# 3          GateRite  Civilian Transports       Probe-Bodyne Hecs
# 4  Plasma Solutions  Civilian Transports  Thick Fuselage Plating
#
#   product_business_line_leader    part_fit_grading  product_key  \
# 0             Shannon Trujillo  Original Equipment      1000101
# 1                 Britt Martin  Original Equipment      1000102
# 2                 Luigi Rudolf  Original Equipment      1000103
# 3                Heather Kosak  Original Equipment      1000104
# 4                 Britt Martin  Original Equipment      1000105
#
#                         subtype            type  weight_tonnes  \
# 0  Liquid Fuel Tanks & Adapters   Fuel & Piping          0.378
# 1           Light Armor Plating  Hull & Shields         0.0751
# 2        Beams, Panels & Radial      Structural          0.482
# 3                       Cockpit         Modules          0.311
# 4           Thick Armor Plating  Hull & Shields         0.7226
#
#    maximum_temperature_k  velocity_tolerance_meters_second  tolerance_g   mk  \
# 0                   2058                                 7           51  MK1
# 1                   2257                                 6           58  MK1
# 2                   2077                                16           54  MK2
# 3                   1237                                18           47  MK2
# 4                   1855                                16           51  MK2
#
#    color production_series                       nameplate  \
# 0   Blue      SERIES NW-86               Frey and Sons Inc
# 1   Teal      SERIES YU-51               Ellis-Johnson PLC
# 2   Gray      SERIES XC-16  Cummings, Valdez and Blair Inc
# 3   Navy      SERIES IV-06         Pope, Bass and Long PLC
# 4  Green      SERIES KH-05         Pope, Bass and Long PLC
#
#                                           material           dwcreateddate
# 0     SERIES NW-86 Liquid Fuel Fuselage MK1 (Blue) 2023-02-10 14:52:07.873
# 1       SERIES YU-51 Light Nose Plating MK1 (Teal) 2023-02-10 14:52:07.873
# 2    SERIES XC-16 Cubic Octagonal Strut MK2 (Gray) 2023-02-10 14:52:07.873
# 3        SERIES IV-06 Probe-Bodyne Hecs MK2 (Navy) 2023-02-10 14:52:07.873
# 4  SERIES KH-05 Thick Fuselage Plating MK2 (Green) 2023-02-10 14:52:07.873
# --- dim.Regions ---
#     table_name  row_count  column_count
# 0  dim.Regions        181            12
#                       column           dtype  nulls  null_pct  distinct  \
# 6                   tax_rate         Float64      0       0.0        21
# 11             dwcreateddate  datetime64[ns]      0       0.0         1
# 0                        all          string      0       0.0         1
# 2      interplanetary_region          string      0       0.0        15
# 4                    station          string      0       0.0       181
# 8     station_sales_managers          string      0       0.0       122
# 5               station_type          string      0       0.0         3
# 1                     system          string      0       0.0         6
# 9   system_regional_managers          string      0       0.0        15
# 7     system_sales_directors          string      0       0.0         5
# 3                  territory          string      0       0.0        57
# 10       territory_directors          string      0       0.0        46
#
#                                        example_values    avg_len  \
# 6                                   [0.02, 0.0, 0.02]        NaN
# 11  [2023-02-10 14:52:09.130000, 2023-02-10 14:52:...        NaN
# 0                                     [All, All, All]   3.000000
# 2   [Îlos VI-VII Region, Transit Gate Region, Îlos...  16.138122
# 4   [Affligem Station, AG Refueling & Supply Stati...  14.237569
# 8   [Nicoletta Burcardo, Fermín Serraglio, Madelei...  13.917127
# 5                         [Station, Station, Station]   6.519337
# 1            [Îlos System, Transit Gate, Îlos System]  11.364641
# 9     [Nicholas Basa, Amy Blankenship, Nicholas Basa]  14.696133
# 7   [Victor Canales, Garrett Novotná, Victor Canales]  12.552486
# 3                  [Îlos VII, Arcadia Gate, Îlos VII]   8.071823
# 10   [Patrick Larson, Michael Huerta, Patrick Larson]  13.541436
#
#                            min                         max      mean
# 6                          0.0                         0.4  0.071685
# 11  2023-02-10 14:52:09.130000  2023-02-10 14:52:09.130000       NaN
# 0                          NaN                         NaN       NaN
# 2                          NaN                         NaN       NaN
# 4                          NaN                         NaN       NaN
# 8                          NaN                         NaN       NaN
# 5                          NaN                         NaN       NaN
# 1                          NaN                         NaN       NaN
# 9                          NaN                         NaN       NaN
# 7                          NaN                         NaN       NaN
# 3                          NaN                         NaN       NaN
# 10                         NaN                         NaN       NaN
#    all        system interplanetary_region     territory  \
# 0  All   Îlos System    Îlos VI-VII Region      Îlos VII
# 1  All  Transit Gate   Transit Gate Region  Arcadia Gate
# 2  All   Îlos System    Îlos VI-VII Region      Îlos VII
# 3  All    Sol System          Sol V Region            Io
# 4  All   Îlos System        Îlos IV Region       Îlos IV
#
#                          station station_type  tax_rate  \
# 0               Affligem Station      Station      0.02
# 1  AG Refueling & Supply Station      Station       0.0
# 2             Andromedus Station      Station      0.02
# 3                  Ao Substation      Station      0.04
# 4                 Apollo Station      Station       0.2
#
#   system_sales_directors station_sales_managers system_regional_managers  \
# 0         Victor Canales     Nicoletta Burcardo            Nicholas Basa
# 1        Garrett Novotná       Fermín Serraglio          Amy Blankenship
# 2         Victor Canales       Madeleine Valdez            Nicholas Basa
# 3            Martine Roś          Shade Tabaxii             Alyssa Ariño
# 4         Victor Canales            Felisa Long  Christopher Jędraszczyk
#
#   territory_directors           dwcreateddate
# 0      Patrick Larson 2023-02-10 14:52:09.130
# 1      Michael Huerta 2023-02-10 14:52:09.130
# 2      Patrick Larson 2023-02-10 14:52:09.130
# 3       Agnès Poirier 2023-02-10 14:52:09.130
# 4       Evita Calgari 2023-02-10 14:52:09.130

# %%
# Une todos los perfiles de columnas en un solo catálogo
catalog_all = pd.concat([
    dim_brands_cols, dim_budget_rate_cols, dim_customers_cols, dim_employees_cols,
    dim_exchange_rate_cols, dim_invoice_dtype_cols, dim_order_dtype_cols,
    dim_order_status_cols, dim_products_cols, dim_regions_cols
], ignore_index=True)

# Resumen por tabla
summary_all = pd.concat([
    dim_brands_sum, dim_budget_rate_sum, dim_customers_sum, dim_employees_sum,
    dim_exchange_rate_sum, dim_invoice_dtype_sum, dim_order_dtype_sum,
    dim_order_status_sum, dim_products_sum, dim_regions_sum
], ignore_index=True)

# %%
catalog_all
# Out:
#                       column           dtype  nulls  null_pct  distinct  \
# 0                   flagship          string      0       0.0         3
# 1                      class          string      0       0.0         2
# 2                       type          string      0       0.0         4
# 3                      brand          string      0       0.0        14
# 4                  sub_brand          string      0       0.0        20
# ..                       ...             ...    ...       ...       ...
# 79    system_sales_directors          string      0       0.0         5
# 80    station_sales_managers          string      0       0.0       122
# 81  system_regional_managers          string      0       0.0        15
# 82       territory_directors          string      0       0.0        46
# 83             dwcreateddate  datetime64[ns]      0       0.0         1
#
#                                        example_values    avg_len  \
# 0             [Other Brand, Other Brand, Other Brand]  12.500000
# 1       [Private Brand, Private Brand, Private Brand]  14.800000
# 2                            [Value, Standard, Value]   6.650000
# 3                            [ASAN, Bruis, FixIt Co.]   6.550000
# 4             [ASAN Terran Systems, Bruis, FixIt Co.]  10.950000
# ..                                                ...        ...
# 79  [Victor Canales, Garrett Novotná, Victor Canales]  12.552486
# 80  [Nicoletta Burcardo, Fermín Serraglio, Madelei...  13.917127
# 81    [Nicholas Basa, Amy Blankenship, Nicholas Basa]  14.696133
# 82   [Patrick Larson, Michael Huerta, Patrick Larson]  13.541436
# 83  [2023-02-10 14:52:09.130000, 2023-02-10 14:52:...        NaN
#
#                            min                         max mean
# 0                          NaT                         NaT  NaN
# 1                          NaT                         NaT  NaN
# 2                          NaT                         NaT  NaN
# 3                          NaT                         NaT  NaN
# 4                          NaT                         NaT  NaN
# ..                         ...                         ...  ...
# 79                         NaN                         NaN  NaN
# 80                         NaN                         NaN  NaN
# 81                         NaN                         NaN  NaN
# 82                         NaN                         NaN  NaN
# 83  2023-02-10 14:52:09.130000  2023-02-10 14:52:09.130000  NaN
#
# [84 rows x 10 columns]

# %%
summary_all
# Out:
#             table_name  row_count  column_count
# 0           dim.Brands         20             7
# 1      dim.Budget-Rate         15             5
# 2        dim.Customers       3911            10
# 3        dim.Employees        893             5
# 4    dim.Exchange-Rate      57900             9
# 5  dim.Invoice-DocType          5             6
# 6    dim.Order-DocType          4             6
# 7     dim.Order-Status          6             6
# 8         dim.Products     256293            18
# 9          dim.Regions        181            12
